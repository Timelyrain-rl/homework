# %%
class NaiveBayes:

    def __init__(self):

        self.vocab = set() # set of unique words in the training set

        self.class_word_freq = {} # word frequency count for each class

        self.class_total_words = {} # total word count for each class

        self.classes = [] # unique classes in the training set

    def train(self, X, Y):

        """

        Train the Naive Bayes classifier on the given training data.

        X: list of training instances (list of strings)

        Y: list of training labels (list of strings)

       """
        
    def predict(self, X):

        """

        Predict the class labels for the given test data.

        X: list of test instances (list of strings)

        Returns: list of predicted labels (list of strings)

        """
        
        return predictions
